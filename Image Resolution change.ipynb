# %%
from PIL import Image

# %%
image_file = Image.open("images/circles.jpg")
image_file
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x1C9B45B9AC8>

# %%
im_resized = image_file.resize((200,200), Image.ANTIALIAS)
im_resized
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x1C9B4584188>
