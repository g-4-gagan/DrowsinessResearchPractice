# %%
# pip install mtcnn

# %%
pip show mtcnn
# Out:
# Name: mtcnnNote: you may need to restart the kernel to use updated packages.
# Version: 0.1.1
# Summary: Multi-task Cascaded Convolutional Neural Networks for Face Detection, based on TensorFlow
# Home-page: http://github.com/ipazc/mtcnn
# Author: Iván de Paz Centeno
# Author-email: ipazc@unileon.es
# License: MIT
# Location: c:\users\hp\appdata\local\programs\python\python37\lib\site-packages
# Requires: keras, opencv-python
# Required-by:

# %%
# pip install tensorflow

# %%
import cv2
import mtcnn
print(mtcnn.__version__)
# Out:
# 0.1.0

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('test2.jpg')
plt.imshow(img)

# %%
# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
    data = plt.imread(filename)
    for result in result_list:
        x, y, w, h = result['box']
        x2, y2 = x + w, y + h
        cv2.rectangle(img, (x, y), (x2, y2), (0,0,255), 1)
#         for key, value in result['keypoints'].items():
#             cv2.circle(value, radius=2, color='red')
    plt.figure(figsize=(10,12))
    plt.imshow(img)
    plt.show()

# %%
detector = mtcnn.MTCNN()
# detect faces in the image
faces = detector.detect_faces(img)
# display faces on the original image
draw_image_with_boxes('test2.jpg', faces)
