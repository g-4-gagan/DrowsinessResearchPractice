# %%
# pip install opencv-python
# Out:
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\hp\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.5.5

# %% [markdown]
# openCV provides a number of pre-trained models as part of the installation. These are available on your system and are also available on the https://github.com/opencv/opencv/tree/master/data/haarcascades

# %%
classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('test2.jpg')
# img = cv2.imread('test2.jpg')

# %%
plt.imshow(img)

# %%
faces = classifier.detectMultiScale(img)

# %%
for face in faces:
    print(face)
# Out:
# [208 263  47  47]
# [451 262  40  40]
# [316 269  44  44]
# [253 145  45  45]
# [ 97 268  47  47]
# [313 248  55  55]
# [258  18  64  64]
# [335  29  34  34]
# [219  40  42  42]
# [128  29  41  41]
# [428  48  37  37]
# [365 155  44  44]
# [153 148  42  42]
# [505 156  39  39]

# %%
for face in faces:
    x,y,w,h = face
    x2, y2 = x + w, y + h
    #draw a rectangle over the pixels
    cv2.rectangle(img, (x, y), (x2, y2), (0,0,255), 1)
plt.figure(figsize=(10,12))
plt.imshow(img)
plt.show()
